# %%
# Libraries used
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from scipy.stats import chi2_contingency
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from datetime import time

# %%
# Then read the CSV and create the new column
df = pd.read_csv('eurocup.csv', encoding='latin-1')

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df.columns = df.columns.str.lower()

# %%
# First, remove all spaces from the column
df['playtype'] = df['playtype'].str.strip()

# Create a dictionary for the mapping
mapping = {
    'LAYUPMD': '2FGM',
    'DUNK': '2FGM',
    'LAYUPATT': '2FGA',
    '2FGAB': '2FGA',
    '3FGAB': '3FGA'
}

# Apply the mapping
df['playtype'] = df['playtype'].replace(mapping)

# %%
# Step 1: Normalize "markertime" to a string format if it contains `datetime.time` objects
df['markertime'] = df['markertime'].apply(lambda x: x.strftime('%M:%S') if isinstance(x, pd._libs.tslibs.nattype.NaTType) else str(x))

# Step 2: Convert the "markertime" column to a timedelta format
df['markertime'] = pd.to_timedelta(df['markertime'], errors='coerce')

# Step 3: Identify games where "markertime" exceeds 00:10:00
invalid_games = df.loc[df['markertime'] > pd.Timedelta(minutes=10), 'game_id'].unique()

# Step 4: Filter out these invalid games from the dataframe
df = df[~df['game_id'].isin(invalid_games)]

# %%
def assign_quarter(minute):
    if minute < 11:
        return 1
    elif minute < 21:
        return 2
    elif minute < 31:
        return 3
    else:
        return 4

# Create new quarter column
df['quarter'] = df['minute'].apply(assign_quarter)

# %%
# Store initial count
initial_rows = len(df)

# List of playtypes to remove
playtypes_to_remove = ['EP', 'EG', 'BP', 'TPOFF', 'JB']

# Remove rows where playtype is in the list
df = df[~df['playtype'].isin(playtypes_to_remove)]

# Print results
rows_removed = initial_rows - len(df)
print(f"Rows removed: {rows_removed}")
print(f"New DataFrame shape: {df.shape}")

# Verify remaining playtypes
print("\nRemaining playtypes:")
print(df['playtype'].unique())
# Out:
# Rows removed: 8802
# New DataFrame shape: (511882, 14)
#
# Remaining playtypes:
# ['TO' 'ST' '2FGM' 'AS' '2FGA' 'O' '3FGA' 'D' 'CM' 'RV' 'IN' 'OUT' '3FGM'
#  'FTM' 'TOUT' 'OF' 'FTA' 'AG' 'FV' 'CMT' 'CMU' 0 'TOUT_TV' 'C' 'B' 'CMD'
#  'F']

# %%
df = df[df["playtype"] != 0]
df["markertime"] = df["markertime"].astype(str)
df["markertime"] = df["markertime"].str.replace("0 days 00:", "")

# %%
def fill_running_scores(df):
    """
    Forward fills basketball scores, converting rows with 0-0 to show running totals.
    
    Parameters:
    df (pandas.DataFrame): DataFrame containing columns 'points_a' and 'points_b'
    
    Returns:
    pandas.DataFrame: DataFrame with running totals for both teams
    """
    # Create a copy to avoid modifying the original DataFrame
    result_df = df.copy()
    
    # Convert 0s to NaN where both scores are 0
    mask = (result_df["points_a"] == 0) & (result_df["points_b"] == 0)
    result_df.loc[mask, ["points_a", "points_b"]] = np.nan
    
    # Forward fill the NaN values
    result_df["points_a"] = result_df["points_a"].fillna(method="ffill").fillna(0)
    result_df["points_b"] = result_df["points_b"].fillna(method="ffill").fillna(0)
    
    # Convert back to integers since scores should be whole numbers
    result_df["points_a"] = result_df["points_a"].astype(int)
    result_df["points_b"] = result_df["points_b"].astype(int)
    
    return result_df

df = fill_running_scores(df)
# Out:
# C:\Users\masii\AppData\Local\Temp\ipykernel_20252\3129420200.py:19: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_df["points_a"] = result_df["points_a"].fillna(method="ffill").fillna(0)
# C:\Users\masii\AppData\Local\Temp\ipykernel_20252\3129420200.py:20: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   result_df["points_b"] = result_df["points_b"].fillna(method="ffill").fillna(0)

# %%
df["plus_minus"] = df["points_a"] - df["points_b"]

# %%
def convert_time_to_seconds(time_str):
    """
    Convert time string from 'mm:ss' format to seconds
    
    Parameters:
    time_str: string in format 'mm:ss' (e.g., '10:00', '09:45', '00:30')
    
    Returns:
    int: total seconds
    """
    minutes, seconds = time_str.split(":")
    return int(minutes) * 60 + int(seconds)

# Apply the conversion
df["seconds"] = df["markertime"].apply(convert_time_to_seconds)
# Out:
#      unnamed: 0  numberofplay    codeteam playtype                    team  \
# 0          1048             1  OLD              TO  EWE Baskets Oldenburg
# 1          1049             2  BON              ST    Telekom Baskets Bonn
# 2          1050             3  BON            2FGM    Telekom Baskets Bonn
# 3          1051             4  BON              AS    Telekom Baskets Bonn
# 4          1052             5  OLD            2FGM  EWE Baskets Oldenburg
# 5          1053             6  BON            2FGA    Telekom Baskets Bonn
# 6          1054             7  BON               O    Telekom Baskets Bonn
# 7          1055             8  BON            3FGA    Telekom Baskets Bonn
# 8          1056             9  BON               O    Telekom Baskets Bonn
# 9          1057            10  BON            3FGA    Telekom Baskets Bonn
# 10         1058            11  OLD               D  EWE Baskets Oldenburg
# 11         1059            12  BON              CM    Telekom Baskets Bonn
# 12         1060            13  OLD              RV  EWE Baskets Oldenburg
# 13         1061            14  OLD              IN  EWE Baskets Oldenburg
# 14         1062            15  OLD             OUT  EWE Baskets Oldenburg
# 15         1063            16  BON            2FGM    Telekom Baskets Bonn
# 16         1064            17  BON              AS    Telekom Baskets Bonn
# 17         1065            18  OLD            2FGA  EWE Baskets Oldenburg
# 18         1066            19  BON               D    Telekom Baskets Bonn
# 19         1067            20  BON            3FGA    Telekom Baskets Bonn
# 20         1068            21  OLD               D  EWE Baskets Oldenburg
# 21         1069            22  OLD            2FGM  EWE Baskets Oldenburg
# 22         1070            23  OLD              AS  EWE Baskets Oldenburg
# 23         1071            24  OLD              CM  EWE Baskets Oldenburg
# 24         1072            25  BON              RV    Telekom Baskets Bonn
# 25         1073            26  BON            2FGM    Telekom Baskets Bonn
# 26         1074            27  BON              AS    Telekom Baskets Bonn
# 27         1075            28  OLD            2FGM  EWE Baskets Oldenburg
# 28         1076            29  BON            2FGM    Telekom Baskets Bonn
# 29         1077            30  OLD              TO  EWE Baskets Oldenburg
# 30         1078            31  BON            3FGM    Telekom Baskets Bonn
# 31         1079            32  BON              AS    Telekom Baskets Bonn
# 32         1080            33  BON              CM    Telekom Baskets Bonn
# 33         1081            34  OLD              RV  EWE Baskets Oldenburg
# 34         1082            35  OLD              IN  EWE Baskets Oldenburg
# 35         1083            36  OLD             OUT  EWE Baskets Oldenburg
# 36         1084            37  OLD             FTM  EWE Baskets Oldenburg
# 37         1085            38  OLD             FTM  EWE Baskets Oldenburg
# 38         1086            39  OLD              IN  EWE Baskets Oldenburg
# 39         1087            40  OLD             OUT  EWE Baskets Oldenburg
# 40         1088            41  BON            2FGM    Telekom Baskets Bonn
# 41         1089            42  OLD            3FGA  EWE Baskets Oldenburg
# 42         1090            43  BON               D    Telekom Baskets Bonn
# 43         1091            44  OLD              CM  EWE Baskets Oldenburg
# 44         1092            45  BON              RV    Telekom Baskets Bonn
# 45         1093            46  BON              IN    Telekom Baskets Bonn
# 46         1094            47  BON              IN    Telekom Baskets Bonn
# 47         1095            48  BON             OUT    Telekom Baskets Bonn
# 48         1096            49  BON             OUT    Telekom Baskets Bonn
# 49         1097            50  BON            2FGM    Telekom Baskets Bonn
# 50         1098            51  OLD            TOUT  EWE Baskets Oldenburg
# 51         1099            52  OLD            2FGM  EWE Baskets Oldenburg
# 52         1100            53  OLD              AS  EWE Baskets Oldenburg
# 53         1101            54  BON              IN    Telekom Baskets Bonn
# 54         1102            55  BON              IN    Telekom Baskets Bonn
# 55         1103            56  BON              IN    Telekom Baskets Bonn
# 56         1104            57  BON             OUT    Telekom Baskets Bonn
# 57         1105            58  BON             OUT    Telekom Baskets Bonn
# 58         1106            59  BON             OUT    Telekom Baskets Bonn
# 59         1107            60  BON              TO    Telekom Baskets Bonn
# 60         1108            61  OLD              ST  EWE Baskets Oldenburg
# 61         1109            62  OLD              TO  EWE Baskets Oldenburg
# 62         1110            63  BON              ST    Telekom Baskets Bonn
# 63         1111            64  OLD              CM  EWE Baskets Oldenburg
# 64         1112            65  BON              RV    Telekom Baskets Bonn
# 65         1113            66  BON              TO    Telekom Baskets Bonn
# 66         1114            67  OLD            2FGA  EWE Baskets Oldenburg
# 67         1115            68  OLD               D  EWE Baskets Oldenburg
# 68         1116            69  BON              CM    Telekom Baskets Bonn
# 69         1117            70  OLD              RV  EWE Baskets Oldenburg
# 70         1118            71  BON              CM    Telekom Baskets Bonn
# 71         1119            72  OLD              RV  EWE Baskets Oldenburg
# 72         1120            73  OLD            3FGM  EWE Baskets Oldenburg
# 73         1121            74  BON            3FGA    Telekom Baskets Bonn
# 74         1122            75  OLD               D  EWE Baskets Oldenburg
# 75         1123            76  OLD            2FGM  EWE Baskets Oldenburg
# 76         1124            77  OLD              AS  EWE Baskets Oldenburg
# 77         1125            78  BON              TO    Telekom Baskets Bonn
# 78         1126            79  OLD              IN  EWE Baskets Oldenburg
# 79         1127            80  OLD             OUT  EWE Baskets Oldenburg
# 80         1128            81  OLD            3FGM  EWE Baskets Oldenburg
# 81         1129            82  OLD              AS  EWE Baskets Oldenburg
# 82         1130            83  OLD              CM  EWE Baskets Oldenburg
# 83         1131            84  BON              RV    Telekom Baskets Bonn
# 84         1132            85  BON            2FGA    Telekom Baskets Bonn
# 85         1133            86  OLD               D  EWE Baskets Oldenburg
# 86         1134            87  OLD            3FGA  EWE Baskets Oldenburg
# 87         1135            88  BON               D    Telekom Baskets Bonn
# 88         1136            89  BON            3FGM    Telekom Baskets Bonn
# 89         1137            90  BON              AS    Telekom Baskets Bonn
# 90         1138            91  OLD              TO  EWE Baskets Oldenburg
# 91         1139            92  BON              ST    Telekom Baskets Bonn
# 92         1140            93  OLD              IN  EWE Baskets Oldenburg
# 93         1141            94  OLD             OUT  EWE Baskets Oldenburg
# 94         1142            95  BON            2FGM    Telekom Baskets Bonn
# 95         1143            96  BON              AS    Telekom Baskets Bonn
# 96         1144            97  OLD            2FGM  EWE Baskets Oldenburg
# 97         1145            98  OLD              AS  EWE Baskets Oldenburg
# 98         1146            99  BON            2FGA    Telekom Baskets Bonn
# 99         1147           100  OLD               D  EWE Baskets Oldenburg
# 100        1151           101  BON              IN    Telekom Baskets Bonn
# 101        1152           102  BON             OUT    Telekom Baskets Bonn
# 102        1153           103  OLD              IN  EWE Baskets Oldenburg
# 103        1154           104  OLD             OUT  EWE Baskets Oldenburg
# 104        1155           105  OLD              CM  EWE Baskets Oldenburg
# 105        1156           106  BON              RV    Telekom Baskets Bonn
# 106        1157           107  BON            3FGM    Telekom Baskets Bonn
# 107        1158           108  OLD            3FGA  EWE Baskets Oldenburg
# 108        1159           109  OLD               O  EWE Baskets Oldenburg
# 109        1160           110  OLD            2FGM  EWE Baskets Oldenburg
# 110        1161           111  BON              TO    Telekom Baskets Bonn
# 111        1162           112  BON              OF    Telekom Baskets Bonn
# 112        1163           113  OLD              RV  EWE Baskets Oldenburg
# 113        1164           114  OLD            2FGA  EWE Baskets Oldenburg
# 114        1165           115  OLD               O  EWE Baskets Oldenburg
# 115        1166           116  OLD            2FGA  EWE Baskets Oldenburg
# 116        1167           117  OLD               O  EWE Baskets Oldenburg
# 117        1168           118  OLD            3FGA  EWE Baskets Oldenburg
# 118        1169           119  OLD               O  EWE Baskets Oldenburg
# 119        1170           120  OLD            2FGA  EWE Baskets Oldenburg
# 120        1171           121  OLD               O  EWE Baskets Oldenburg
# 121        1172           122  BON              CM    Telekom Baskets Bonn
# 122        1173           123  OLD              RV  EWE Baskets Oldenburg
# 123        1174           124  BON            TOUT    Telekom Baskets Bonn
# 124        1175           125  BON              IN    Telekom Baskets Bonn
# 125        1176           126  BON              IN    Telekom Baskets Bonn
# 126        1177           127  BON             OUT    Telekom Baskets Bonn
# 127        1178           128  BON             OUT    Telekom Baskets Bonn
# 128        1179           129  OLD             FTM  EWE Baskets Oldenburg
# 129        1180           130  OLD             FTM  EWE Baskets Oldenburg
# 130        1181           131  BON            3FGM    Telekom Baskets Bonn
# 131        1182           132  OLD            2FGM  EWE Baskets Oldenburg
# 132        1183           133  BON            3FGM    Telekom Baskets Bonn
# 133        1184           134  BON              AS    Telekom Baskets Bonn
# 134        1185           135  OLD            3FGA  EWE Baskets Oldenburg
# 135        1186           136  OLD               O  EWE Baskets Oldenburg
# 136        1187           137  OLD              TO  EWE Baskets Oldenburg
# 137        1188           138  BON              ST    Telekom Baskets Bonn
# 138        1189           139  BON            2FGA    Telekom Baskets Bonn
# 139        1190           140  OLD               D  EWE Baskets Oldenburg
# 140        1191           141  OLD            3FGM  EWE Baskets Oldenburg
# 141        1192           142  BON              IN    Telekom Baskets Bonn
# 142        1193           143  BON             OUT    Telekom Baskets Bonn
# 143        1194           144  OLD              IN  EWE Baskets Oldenburg
# 144        1195           145  OLD             OUT  EWE Baskets Oldenburg
# 145        1196           146  BON              TO    Telekom Baskets Bonn
# 146        1197           147  OLD              ST  EWE Baskets Oldenburg
# 147        1198           148  OLD              TO  EWE Baskets Oldenburg
# 148        1199           149  BON              ST    Telekom Baskets Bonn
# 149        1200           150  OLD              CM  EWE Baskets Oldenburg
# 150        1201           151  BON              RV    Telekom Baskets Bonn
# 151        1202           152  OLD              IN  EWE Baskets Oldenburg
# 152        1203           153  OLD             OUT  EWE Baskets Oldenburg
# 153        1204           154  OLD              CM  EWE Baskets Oldenburg
# 154        1205           155  BON              RV    Telekom Baskets Bonn
# 155        1206           156  OLD              IN  EWE Baskets Oldenburg
# 156        1207           157  OLD             OUT  EWE Baskets Oldenburg
# 157        1208           158  BON             FTM    Telekom Baskets Bonn
# 158        1209           159  BON              AS    Telekom Baskets Bonn
# 159        1210           160  BON             FTM    Telekom Baskets Bonn
# 160        1211           161  OLD              TO  EWE Baskets Oldenburg
# 161        1212           162  BON            3FGA    Telekom Baskets Bonn
# 162        1213           163  OLD               D  EWE Baskets Oldenburg
# 163        1214           164  OLD            2FGA  EWE Baskets Oldenburg
# 164        1215           165  BON               D    Telekom Baskets Bonn
# 165        1216           166  BON            2FGM    Telekom Baskets Bonn
# 166        1217           167  OLD            TOUT  EWE Baskets Oldenburg
# 167        1218           168  BON              IN    Telekom Baskets Bonn
# 168        1219           169  BON             OUT    Telekom Baskets Bonn
# 169        1220           170  OLD              IN  EWE Baskets Oldenburg
# 170        1221           171  OLD             OUT  EWE Baskets Oldenburg
# 171        1222           172  OLD            2FGA  EWE Baskets Oldenburg
# 172        1223           173  BON               D    Telekom Baskets Bonn
# 173        1224           174  OLD              IN  EWE Baskets Oldenburg
# 174        1225           175  OLD             OUT  EWE Baskets Oldenburg
# 175        1226           176  BON            2FGM    Telekom Baskets Bonn
# 176        1227           177  OLD              TO  EWE Baskets Oldenburg
# 177        1228           178  BON            2FGM    Telekom Baskets Bonn
# 178        1229           179  OLD            2FGA  EWE Baskets Oldenburg
# 179        1230           180  OLD               O  EWE Baskets Oldenburg
# 180        1231           181  OLD            2FGM  EWE Baskets Oldenburg
# 181        1232           182  OLD              AS  EWE Baskets Oldenburg
# 182        1233           183  BON            2FGM    Telekom Baskets Bonn
# 183        1234           184  OLD            2FGA  EWE Baskets Oldenburg
# 184        1235           185  BON               D    Telekom Baskets Bonn
# 185        1236           186  BON              TO    Telekom Baskets Bonn
# 186        1237           187  BON              IN    Telekom Baskets Bonn
# 187        1238           188  BON             OUT    Telekom Baskets Bonn
# 188        1239           189  OLD              IN  EWE Baskets Oldenburg
# 189        1240           190  OLD              IN  EWE Baskets Oldenburg
# 190        1241           191  OLD             OUT  EWE Baskets Oldenburg
# 191        1242           192  OLD             OUT  EWE Baskets Oldenburg
# 192        1243           193  OLD            2FGM  EWE Baskets Oldenburg
# 193        1244           194  OLD              AS  EWE Baskets Oldenburg
# 194        1245           195  OLD              CM  EWE Baskets Oldenburg
# 195        1246           196  BON              RV    Telekom Baskets Bonn
# 196        1247           197  BON              IN    Telekom Baskets Bonn
# 197        1248           198  BON             OUT    Telekom Baskets Bonn
# 198        1249           199  BON             FTM    Telekom Baskets Bonn
# 199        1250           200  BON             FTM    Telekom Baskets Bonn
# 200        1251           201  OLD            3FGA  EWE Baskets Oldenburg
# 201        1252           202  BON               D    Telekom Baskets Bonn
# 202        1253           203  BON            2FGA    Telekom Baskets Bonn
# 203        1254           204  OLD               D  EWE Baskets Oldenburg
# 204        1255           205  OLD            3FGM  EWE Baskets Oldenburg
# 205        1256           206  OLD              AS  EWE Baskets Oldenburg
# 206        1257           207  BON            2FGM    Telekom Baskets Bonn
# 207        1258           208  BON              CM    Telekom Baskets Bonn
# 208        1259           209  OLD              RV  EWE Baskets Oldenburg
# 209        1260           210  BON              IN    Telekom Baskets Bonn
# 210        1261           211  BON             OUT    Telekom Baskets Bonn
# 211        1262           212  OLD            2FGM  EWE Baskets Oldenburg
# 212        1263           213  OLD              AS  EWE Baskets Oldenburg
# 213        1264           214  BON            2FGA    Telekom Baskets Bonn
# 214        1265           215  OLD               D  EWE Baskets Oldenburg
# 215        1268           216  BON              IN    Telekom Baskets Bonn
# 216        1269           217  BON              IN    Telekom Baskets Bonn
# 217        1270           218  BON              IN    Telekom Baskets Bonn
# 218        1271           219  BON             OUT    Telekom Baskets Bonn
# 219        1272           220  BON             OUT    Telekom Baskets Bonn
# 220        1273           221  BON             OUT    Telekom Baskets Bonn
# 221        1274           222  OLD              IN  EWE Baskets Oldenburg
# 222        1275           223  OLD             OUT  EWE Baskets Oldenburg
# 223        1276           224  OLD              TO  EWE Baskets Oldenburg
# 224        1277           225  BON              ST    Telekom Baskets Bonn
# 225        1278           226  BON            2FGM    Telekom Baskets Bonn
# 226        1279           227  OLD            2FGM  EWE Baskets Oldenburg
# 227        1280           228  BON            3FGA    Telekom Baskets Bonn
# 228        1281           229  BON               O    Telekom Baskets Bonn
# 229        1282           230  OLD              CM  EWE Baskets Oldenburg
# 230        1283           231  BON              RV    Telekom Baskets Bonn
# 231        1284           232  BON              TO    Telekom Baskets Bonn
# 232        1285           233  OLD              IN  EWE Baskets Oldenburg
# 233        1286           234  OLD             OUT  EWE Baskets Oldenburg
# 234        1287           235  OLD            2FGA  EWE Baskets Oldenburg
# 235        1288           236  BON               D    Telekom Baskets Bonn
# 236        1289           237  BON            3FGM    Telekom Baskets Bonn
# 237        1290           238  OLD            2FGM  EWE Baskets Oldenburg
# 238        1291           239  OLD              AS  EWE Baskets Oldenburg
# 239        1292           240  BON            2FGA    Telekom Baskets Bonn
# 240        1293           241  OLD               D  EWE Baskets Oldenburg
# 241        1294           242  BON              CM    Telekom Baskets Bonn
# 242        1295           243  OLD            3FGM  EWE Baskets Oldenburg
# 243        1296           244  OLD              AS  EWE Baskets Oldenburg
# 244        1297           245  BON            3FGA    Telekom Baskets Bonn
# 245        1298           246  BON               O    Telekom Baskets Bonn
# 246        1299           247  OLD              CM  EWE Baskets Oldenburg
# 247        1300           248  BON              RV    Telekom Baskets Bonn
# 248        1301           249  BON            2FGM    Telekom Baskets Bonn
# 249        1302           250  BON              AS    Telekom Baskets Bonn
# 250        1303           251  OLD            2FGM  EWE Baskets Oldenburg
# 251        1304           252  BON            TOUT    Telekom Baskets Bonn
# 252        1305           253  OLD              IN  EWE Baskets Oldenburg
# 253        1306           254  OLD              IN  EWE Baskets Oldenburg
# 254        1307           255  OLD             OUT  EWE Baskets Oldenburg
# 255        1308           256  OLD             OUT  EWE Baskets Oldenburg
# 256        1309           257  BON            2FGA    Telekom Baskets Bonn
# 257        1310           258  BON               O    Telekom Baskets Bonn
# 258        1311           259  BON            2FGM    Telekom Baskets Bonn
# 259        1312           260  BON              AS    Telekom Baskets Bonn
# 260        1313           261  BON              CM    Telekom Baskets Bonn
# 261        1314           262  OLD              RV  EWE Baskets Oldenburg
# 262        1315           263  OLD              TO  EWE Baskets Oldenburg
# 263        1316           264  BON              ST    Telekom Baskets Bonn
# 264        1317           265  BON            2FGM    Telekom Baskets Bonn
# 265        1318           266  OLD            2FGA  EWE Baskets Oldenburg
# 266        1319           267  BON               D    Telekom Baskets Bonn
# 267        1320           268  BON              TO    Telekom Baskets Bonn
# 268        1321           269  OLD              ST  EWE Baskets Oldenburg
# 269        1322           270  OLD            3FGM  EWE Baskets Oldenburg
# 270        1323           271  OLD              AS  EWE Baskets Oldenburg
# 271        1324           272  OLD              CM  EWE Baskets Oldenburg
# 272        1325           273  BON              RV    Telekom Baskets Bonn
# 273        1326           274  BON              IN    Telekom Baskets Bonn
# 274        1327           275  BON              IN    Telekom Baskets Bonn
# 275        1328           276  BON             OUT    Telekom Baskets Bonn
# 276        1329           277  BON             OUT    Telekom Baskets Bonn
# 277        1330           278  OLD              IN  EWE Baskets Oldenburg
# 278        1331           279  OLD             OUT  EWE Baskets Oldenburg
# 279        1332           280  OLD              CM  EWE Baskets Oldenburg
# 280        1333           281  BON              RV    Telekom Baskets Bonn
# 281        1334           282  BON              IN    Telekom Baskets Bonn
# 282        1335           283  BON             OUT    Telekom Baskets Bonn
# 283        1336           284  BON             FTM    Telekom Baskets Bonn
# 284        1337           285  BON             FTM    Telekom Baskets Bonn
# 285        1338           286  OLD            3FGM  EWE Baskets Oldenburg
# 286        1339           287  BON            3FGA    Telekom Baskets Bonn
# 287        1340           288  BON               O    Telekom Baskets Bonn
# 288        1341           289  BON            2FGM    Telekom Baskets Bonn
# 289        1342           290  OLD            2FGM  EWE Baskets Oldenburg
# 290        1343           291  OLD              AS  EWE Baskets Oldenburg
# 291        1344           292  BON              IN    Telekom Baskets Bonn
# 292        1345           293  BON              IN    Telekom Baskets Bonn
# 293        1346           294  BON             OUT    Telekom Baskets Bonn
# 294        1347           295  BON             OUT    Telekom Baskets Bonn
# 295        1348           296  BON              TO    Telekom Baskets Bonn
# 296        1349           297  BON              OF    Telekom Baskets Bonn
# 297        1350           298  OLD              RV  EWE Baskets Oldenburg
# 298        1351           299  OLD            2FGM  EWE Baskets Oldenburg
# 299        1352           300  BON              TO    Telekom Baskets Bonn
# 300        1353           301  OLD              ST  EWE Baskets Oldenburg
# 301        1354           302  OLD            2FGA  EWE Baskets Oldenburg
# 302        1355           303  OLD               O  EWE Baskets Oldenburg
# 303        1356           304  OLD            2FGM  EWE Baskets Oldenburg
# 304        1357           305  OLD              CM  EWE Baskets Oldenburg
# 305        1358           306  BON              RV    Telekom Baskets Bonn
# 306        1359           307  OLD              IN  EWE Baskets Oldenburg
# 307        1360           308  OLD             OUT  EWE Baskets Oldenburg
# 308        1361           309  BON             FTM    Telekom Baskets Bonn
# 309        1362           310  BON             FTM    Telekom Baskets Bonn
# 310        1363           311  OLD            2FGA  EWE Baskets Oldenburg
# 311        1364           312  BON               D    Telekom Baskets Bonn
# 312        1365           313  BON            2FGM    Telekom Baskets Bonn
# 313        1366           314  BON              AS    Telekom Baskets Bonn
# 314        1367           315  OLD              CM  EWE Baskets Oldenburg
# 315        1368           316  BON              RV    Telekom Baskets Bonn
# 316        1369           317  OLD              IN  EWE Baskets Oldenburg
# 317        1370           318  OLD             OUT  EWE Baskets Oldenburg
# 318        1371           319  BON             FTA    Telekom Baskets Bonn
# 319        1372           320  OLD               D  EWE Baskets Oldenburg
# 320        1373           321  OLD            2FGM  EWE Baskets Oldenburg
# 321        1374           322  BON            3FGA    Telekom Baskets Bonn
# 322        1375           323  OLD               D  EWE Baskets Oldenburg
# 323        1376           324  OLD              TO  EWE Baskets Oldenburg
# 324        1377           325  BON              IN    Telekom Baskets Bonn
# 325        1378           326  BON             OUT    Telekom Baskets Bonn
# 326        1379           327  OLD              IN  EWE Baskets Oldenburg
# 327        1380           328  OLD             OUT  EWE Baskets Oldenburg
# 328        1381           329  OLD              CM  EWE Baskets Oldenburg
# 329        1382           330  BON              RV    Telekom Baskets Bonn
# 330        1383           331  BON             FTM    Telekom Baskets Bonn
# 331        1384           332  BON             FTA    Telekom Baskets Bonn
# 332        1385           333  BON               O    Telekom Baskets Bonn
# 333        1386           334  OLD              CM  EWE Baskets Oldenburg
# 334        1387           335  BON              RV    Telekom Baskets Bonn
# 335        1388           336  BON             FTM    Telekom Baskets Bonn
# 336        1389           337  BON             FTA    Telekom Baskets Bonn
# 337        1390           338  OLD               D  EWE Baskets Oldenburg
# 338        1391           339  BON              CM    Telekom Baskets Bonn
# 339        1392           340  OLD              RV  EWE Baskets Oldenburg
# 340        1393           341  OLD              AG  EWE Baskets Oldenburg
# 341        1394           342  BON              FV    Telekom Baskets Bonn
# 342        1395           343  OLD               O  EWE Baskets Oldenburg
# 343        1396           344  OLD            2FGM  EWE Baskets Oldenburg
# 344        1397           345  BON            2FGA    Telekom Baskets Bonn
# 345        1398           346  OLD              FV  EWE Baskets Oldenburg
# 346        1399           347  BON               D    Telekom Baskets Bonn
# 347        1400           348  BON            2FGM    Telekom Baskets Bonn
# 348        1401           349  OLD            2FGA  EWE Baskets Oldenburg
# 349        1402           350  BON              AG    Telekom Baskets Bonn
# 350        1406           351  OLD              IN  EWE Baskets Oldenburg
# 351        1407           352  OLD              IN  EWE Baskets Oldenburg
# 352        1408           353  OLD             OUT  EWE Baskets Oldenburg
# 353        1409           354  OLD             OUT  EWE Baskets Oldenburg
# 354        1410           355  BON            2FGA    Telekom Baskets Bonn
# 355        1411           356  OLD               D  EWE Baskets Oldenburg
# 356        1412           357  OLD            2FGA  EWE Baskets Oldenburg
# 357        1413           358  OLD              AG  EWE Baskets Oldenburg
# 358        1414           359  BON              FV    Telekom Baskets Bonn
# 359        1415           360  BON               D    Telekom Baskets Bonn
# 360        1416           361  BON            3FGM    Telekom Baskets Bonn
# 361        1417           362  OLD            3FGA  EWE Baskets Oldenburg
# 362        1418           363  BON               D    Telekom Baskets Bonn
# 363        1419           364  BON              TO    Telekom Baskets Bonn
# 364        1420           365  OLD            2FGM  EWE Baskets Oldenburg
# 365        1421           366  OLD              AS  EWE Baskets Oldenburg
# 366        1422           367  BON              TO    Telekom Baskets Bonn
# 367        1423           368  OLD              ST  EWE Baskets Oldenburg
# 368        1424           369  OLD            2FGM  EWE Baskets Oldenburg
# 369        1425           370  BON            TOUT    Telekom Baskets Bonn
# 370        1426           371  BON              IN    Telekom Baskets Bonn
# 371        1427           372  BON             OUT    Telekom Baskets Bonn
# 372        1428           373  BON            3FGM    Telekom Baskets Bonn
# 373        1429           374  OLD            2FGA  EWE Baskets Oldenburg
# 374        1430           375  BON               D    Telekom Baskets Bonn
# 375        1431           376  BON              TO    Telekom Baskets Bonn
# 376        1432           377  OLD              ST  EWE Baskets Oldenburg
# 377        1433           378  OLD            3FGA  EWE Baskets Oldenburg
# 378        1434           379  OLD               O  EWE Baskets Oldenburg
# 379        1435           380  BON              CM    Telekom Baskets Bonn
# 380        1436           381  OLD              RV  EWE Baskets Oldenburg
# 381        1437           382  BON              IN    Telekom Baskets Bonn
# 382        1438           383  BON              IN    Telekom Baskets Bonn
# 383        1439           384  BON             OUT    Telekom Baskets Bonn
# 384        1440           385  BON             OUT    Telekom Baskets Bonn
# 385        1441           386  OLD              IN  EWE Baskets Oldenburg
# 386        1442           387  OLD             OUT  EWE Baskets Oldenburg
# 387        1443           388  OLD            2FGA  EWE Baskets Oldenburg
# 388        1444           389  BON               D    Telekom Baskets Bonn
# 389        1445           390  BON            2FGM    Telekom Baskets Bonn
# 390        1446           391  OLD            TOUT  EWE Baskets Oldenburg
# 391        1447           392  OLD              IN  EWE Baskets Oldenburg
# 392        1448           393  OLD              IN  EWE Baskets Oldenburg
# 393        1449           394  OLD             OUT  EWE Baskets Oldenburg
# 394        1450           395  OLD             OUT  EWE Baskets Oldenburg
# 395        1451           396  OLD            2FGA  EWE Baskets Oldenburg
# 396        1452           397  BON               D    Telekom Baskets Bonn
# 397        1453           398  BON            2FGA    Telekom Baskets Bonn
# 398        1454           399  OLD               D  EWE Baskets Oldenburg
# 399        1455           400  OLD            2FGA  EWE Baskets Oldenburg
# 400        1456           401  BON               D    Telekom Baskets Bonn
# 401        1457           402  BON              TO    Telekom Baskets Bonn
# 402        1458           403  OLD              ST  EWE Baskets Oldenburg
# 403        1459           404  BON              CM    Telekom Baskets Bonn
# 404        1460           405  OLD              RV  EWE Baskets Oldenburg
# 405        1461           406  OLD            3FGA  EWE Baskets Oldenburg
# 406        1462           407  OLD               O  EWE Baskets Oldenburg
# 407        1463           408  OLD            3FGA  EWE Baskets Oldenburg
# 408        1464           409  BON               D    Telekom Baskets Bonn
# 409        1465           410  BON            3FGM    Telekom Baskets Bonn
# 410        1466           411  BON              AS    Telekom Baskets Bonn
# 411        1467           412  OLD            TOUT  EWE Baskets Oldenburg
# 412        1468           413  OLD            2FGA  EWE Baskets Oldenburg
# 413        1469           414  BON               D    Telekom Baskets Bonn
# 414        1470           415  BON            3FGA    Telekom Baskets Bonn
# 415        1471           416  OLD               D  EWE Baskets Oldenburg
# 416        1472           417  OLD            3FGA  EWE Baskets Oldenburg
# 417        1473           418  BON               D    Telekom Baskets Bonn
# 418        1474           419  OLD              CM  EWE Baskets Oldenburg
# 419        1475           420  BON              RV    Telekom Baskets Bonn
# 420        1476           421  BON              IN    Telekom Baskets Bonn
# 421        1477           422  BON             OUT    Telekom Baskets Bonn
# 422        1478           423  OLD              IN  EWE Baskets Oldenburg
# 423        1479           424  OLD              IN  EWE Baskets Oldenburg
# 424        1480           425  OLD             OUT  EWE Baskets Oldenburg
# 425        1481           426  OLD             OUT  EWE Baskets Oldenburg
# 426        1482           427  BON            3FGA    Telekom Baskets Bonn
# 427        1483           428  BON              TO    Telekom Baskets Bonn
# 428        1484           429  OLD            2FGM  EWE Baskets Oldenburg
# 429        1485           430  BON            3FGM    Telekom Baskets Bonn
# 430        1486           431  BON              AS    Telekom Baskets Bonn
# 431        1487           432  OLD            3FGA  EWE Baskets Oldenburg
# 432        1488             1  BON               D    Telekom Baskets Bonn
# 433        1489             2  OLD              CM  EWE Baskets Oldenburg
# 434        1490             3  BON              RV    Telekom Baskets Bonn
# 435        1491             4  BON             FTM    Telekom Baskets Bonn
# 436        1492             5  BON             FTM    Telekom Baskets Bonn
# 437        1493             6  BON              CM    Telekom Baskets Bonn
# 438        1494             7  OLD              RV  EWE Baskets Oldenburg
# 439        1495             8  BON              CM    Telekom Baskets Bonn
# 440        1496             9  OLD              RV  EWE Baskets Oldenburg
# 441        1497            10  OLD             FTA  EWE Baskets Oldenburg
# 442        1498            11  OLD             FTM  EWE Baskets Oldenburg
# 443        1499            12  BON              TO    Telekom Baskets Bonn
# 444        1500            13  OLD              ST  EWE Baskets Oldenburg
# 445        1501            14  BON              CM    Telekom Baskets Bonn
# 446        1502            15  OLD              RV  EWE Baskets Oldenburg
# 447        1503            16  OLD             FTM  EWE Baskets Oldenburg
# 448        1504            17  OLD             FTM  EWE Baskets Oldenburg
# 449        1505            18  BON            3FGM    Telekom Baskets Bonn
# 450        1506            19  BON              AS    Telekom Baskets Bonn
# 451        1507            20  OLD            2FGM  EWE Baskets Oldenburg
# 452        1508            21  BON            3FGM    Telekom Baskets Bonn
# 453        1509            22  BON              AS    Telekom Baskets Bonn
# 454        1510            23  OLD            3FGM  EWE Baskets Oldenburg
# 455        1511            24  OLD              AS  EWE Baskets Oldenburg
# 456        1512            25  BON            3FGA    Telekom Baskets Bonn
# 457        1515            26  TOR              TO              Fiat Turin
# 458        1516            27  CED              ST         Cedevita Zagreb
# 459        1517            28  CED            3FGM         Cedevita Zagreb
# 460        1518            29  CED              AS         Cedevita Zagreb
# 461        1519            30  TOR            2FGM              Fiat Turin
# 462        1520            31  CED              TO         Cedevita Zagreb
# 463        1521            32  TOR              ST              Fiat Turin
# 464        1522            33  TOR            2FGA              Fiat Turin
# 465        1523            34  CED               D         Cedevita Zagreb
# 466        1524            35  CED            3FGA         Cedevita Zagreb
# 467        1525            36  TOR               D              Fiat Turin
# 468        1526            37  TOR            2FGM              Fiat Turin
# 469        1527            38  CED            2FGA         Cedevita Zagreb
# 470        1528            39  TOR               D              Fiat Turin
# 471        1529            40  CED              CM         Cedevita Zagreb
# 472        1530            41  TOR              RV              Fiat Turin
# 473        1531            42  TOR             FTM              Fiat Turin
# 474        1532            43  TOR              AS              Fiat Turin
# 475        1533            44  TOR             FTM              Fiat Turin
# 476        1534            45  CED            2FGM         Cedevita Zagreb
# 477        1535            46  CED              AS         Cedevita Zagreb
# 478        1536            47  TOR              TO              Fiat Turin
# 479        1537            48  TOR              OF              Fiat Turin
# 480        1538            49  CED              RV         Cedevita Zagreb
# 481        1539            50  CED            2FGA         Cedevita Zagreb
# 482        1540            51  CED               O         Cedevita Zagreb
# 483        1541            52  CED            2FGA         Cedevita Zagreb
# 484        1542            53  TOR               D              Fiat Turin
# 485        1543            54  TOR              TO              Fiat Turin
# 486        1544            55  CED            2FGA         Cedevita Zagreb
# 487        1545            56  CED               O         Cedevita Zagreb
# 488        1546            57  CED            2FGM         Cedevita Zagreb
# 489        1547            58  TOR            2FGA              Fiat Turin
# 490        1548            59  TOR               O              Fiat Turin
# 491        1549            60  TOR            3FGM              Fiat Turin
# 492        1550            61  CED              TO         Cedevita Zagreb
# 493        1551            62  CED             OUT         Cedevita Zagreb
# 494        1552            63  CED              IN         Cedevita Zagreb
# 495        1553            64  CED              TO         Cedevita Zagreb
# 496        1554            65  TOR              ST              Fiat Turin
# 497        1555            66  TOR            2FGM              Fiat Turin
# 498        1556            67  CED              TO         Cedevita Zagreb
# 499        1557            68  TOR              ST              Fiat Turin
#
#      minute markertime  points_a  points_b  \
# 0         1      09:46         0         0
# 1         1      09:46         0         0
# 2         1      09:32         2         0
# 3         1      09:29         2         0
# 4         1      09:22         2         2
# 5         1      09:22         2         2
# 6         1      09:22         2         2
# 7         1      09:22         2         2
# 8         1      09:22         2         2
# 9         1      09:22         2         2
# 10        1      09:22         2         2
# 11        1      09:22         2         2
# 12        1      09:22         2         2
# 13        1      09:22         2         2
# 14        1      09:22         2         2
# 15        3      07:59         4         2
# 16        3      07:59         4         2
# 17        3      07:53         4         2
# 18        3      07:49         4         2
# 19        3      07:42         4         2
# 20        3      07:39         4         2
# 21        3      07:35         4         4
# 22        3      07:32         4         4
# 23        4      06:58         4         4
# 24        4      06:58         4         4
# 25        4      06:58         6         4
# 26        4      06:58         6         4
# 27        4      06:58         6         6
# 28        4      06:28         8         6
# 29        4      06:16         8         6
# 30        5      05:57        11         6
# 31        5      05:55        11         6
# 32        5      05:43        11         6
# 33        5      05:43        11         6
# 34        5      05:43        11         6
# 35        5      05:43        11         6
# 36        5      05:43        11         7
# 37        5      05:43        11         8
# 38        5      05:43        11         8
# 39        5      05:43        11         8
# 40        5      05:23        13         8
# 41        5      05:07        13         8
# 42        5      05:05        13         8
# 43        5      05:05        13         8
# 44        5      05:05        13         8
# 45        5      05:05        13         8
# 46        5      05:05        13         8
# 47        5      05:05        13         8
# 48        5      05:05        13         8
# 49        6      04:46        15         8
# 50        6      04:46        15         8
# 51        6      04:21        15        10
# 52        6      04:18        15        10
# 53        6      04:01        15        10
# 54        6      04:01        15        10
# 55        6      04:01        15        10
# 56        6      04:01        15        10
# 57        6      04:01        15        10
# 58        6      04:01        15        10
# 59        7      03:57        15        10
# 60        7      03:55        15        10
# 61        7      03:52        15        10
# 62        7      03:52        15        10
# 63        7      03:52        15        10
# 64        7      03:52        15        10
# 65        7      03:39        15        10
# 66        7      03:25        15        10
# 67        7      03:25        15        10
# 68        7      03:25        15        10
# 69        7      03:25        15        10
# 70        7      03:25        15        10
# 71        7      03:25        15        10
# 72        7      03:16        15        13
# 73        8      02:59        15        13
# 74        8      02:56        15        13
# 75        8      02:50        15        15
# 76        8      02:42        15        15
# 77        8      02:37        15        15
# 78        8      02:31        15        15
# 79        8      02:31        15        15
# 80        8      02:11        15        18
# 81        8      02:08        15        18
# 82        9      01:53        15        18
# 83        9      01:53        15        18
# 84        9      01:53        15        18
# 85        9      01:53        15        18
# 86        9      01:25        15        18
# 87        9      01:23        15        18
# 88        9      01:09        18        18
# 89        9      01:07        18        18
# 90       10      00:45        18        18
# 91       10      00:45        18        18
# 92       10      00:45        18        18
# 93       10      00:45        18        18
# 94       10      00:25        20        18
# 95       10      00:23        20        18
# 96       10      00:08        20        20
# 97       10      00:05        20        20
# 98       10      00:00        20        20
# 99       10      00:00        20        20
# 100      11      09:59        20        20
# 101      11      09:59        20        20
# 102      11      09:59        20        20
# 103      11      09:59        20        20
# 104      11      09:48        20        20
# 105      11      09:48        20        20
# 106      11      09:34        23        20
# 107      11      09:17        23        20
# 108      11      09:15        23        20
# 109      11      09:13        23        22
# 110      11      09:01        23        22
# 111      11      09:01        23        22
# 112      11      09:01        23        22
# 113      12      08:46        23        22
# 114      12      08:44        23        22
# 115      12      08:33        23        22
# 116      12      08:30        23        22
# 117      12      08:27        23        22
# 118      12      08:25        23        22
# 119      12      08:23        23        22
# 120      12      08:23        23        22
# 121      12      08:23        23        22
# 122      12      08:23        23        22
# 123      12      08:23        23        22
# 124      12      08:23        23        22
# 125      12      08:23        23        22
# 126      12      08:23        23        22
# 127      12      08:23        23        22
# 128      12      08:23        23        23
# 129      12      08:23        23        24
# 130      12      08:05        26        24
# 131      13      07:40        26        26
# 132      13      07:25        29        26
# 133      13      07:22        29        26
# 134      14      06:56        29        26
# 135      14      06:50        29        26
# 136      14      06:48        29        26
# 137      14      06:46        29        26
# 138      14      06:44        29        26
# 139      14      06:41        29        26
# 140      14      06:26        29        29
# 141      14      06:09        29        29
# 142      14      06:09        29        29
# 143      14      06:09        29        29
# 144      14      06:09        29        29
# 145      14      06:00        29        29
# 146      15      05:58        29        29
# 147      15      05:52        29        29
# 148      15      05:52        29        29
# 149      15      05:52        29        29
# 150      15      05:52        29        29
# 151      15      05:52        29        29
# 152      15      05:52        29        29
# 153      15      05:40        29        29
# 154      15      05:40        29        29
# 155      15      05:40        29        29
# 156      15      05:40        29        29
# 157      15      05:40        30        29
# 158      15      05:40        30        29
# 159      15      05:40        31        29
# 160      15      05:20        31        29
# 161      15      05:09        31        29
# 162      15      05:06        31        29
# 163      16      04:45        31        29
# 164      16      04:42        31        29
# 165      16      04:31        33        29
# 166      16      04:30        33        29
# 167      16      04:30        33        29
# 168      16      04:30        33        29
# 169      16      04:30        33        29
# 170      16      04:30        33        29
# 171      16      04:17        33        29
# 172      16      04:14        33        29
# 173      16      04:06        33        29
# 174      16      04:06        33        29
# 175      17      03:52        35        29
# 176      17      03:36        35        29
# 177      17      03:23        37        29
# 178      17      03:06        37        29
# 179      17      03:03        37        29
# 180      17      03:02        37        31
# 181      17      03:02        37        31
# 182      18      02:40        39        31
# 183      18      02:23        39        31
# 184      18      02:21        39        31
# 185      18      02:18        39        31
# 186      18      02:18        39        31
# 187      18      02:18        39        31
# 188      18      02:18        39        31
# 189      18      02:18        39        31
# 190      18      02:18        39        31
# 191      18      02:18        39        31
# ...
# 272  EWE Baskets Oldenburg   2015_001        3           4      276
# 273  EWE Baskets Oldenburg   2015_001        3           4      276
# 274  EWE Baskets Oldenburg   2015_001        3           4      276
# 275  EWE Baskets Oldenburg   2015_001        3           4      276
# 276  EWE Baskets Oldenburg   2015_001        3           4      276
# 277  EWE Baskets Oldenburg   2015_001        3           4      276
# 278  EWE Baskets Oldenburg   2015_001        3           4      276
# 279  EWE Baskets Oldenburg   2015_001        3           4      274
# 280  EWE Baskets Oldenburg   2015_001        3           4      274
# 281  EWE Baskets Oldenburg   2015_001        3           4      274
# 282  EWE Baskets Oldenburg   2015_001        3           4      274
# 283  EWE Baskets Oldenburg   2015_001        3           5      274
# 284  EWE Baskets Oldenburg   2015_001        3           6      274
# 285  EWE Baskets Oldenburg   2015_001        3           3      260
# 286  EWE Baskets Oldenburg   2015_001        3           3      239
# 287  EWE Baskets Oldenburg   2015_001        3           3      236
# 288  EWE Baskets Oldenburg   2015_001        3           5      233
# 289  EWE Baskets Oldenburg   2015_001        3           3      217
# 290  EWE Baskets Oldenburg   2015_001        3           3      215
# 291  EWE Baskets Oldenburg   2015_001        3           3      206
# 292  EWE Baskets Oldenburg   2015_001        3           3      206
# 293  EWE Baskets Oldenburg   2015_001        3           3      206
# 294  EWE Baskets Oldenburg   2015_001        3           3      206
# 295  EWE Baskets Oldenburg   2015_001        3           3      206
# 296  EWE Baskets Oldenburg   2015_001        3           3      206
# 297  EWE Baskets Oldenburg   2015_001        3           3      206
# 298  EWE Baskets Oldenburg   2015_001        3           1      176
# 299  EWE Baskets Oldenburg   2015_001        3           1      164
# 300  EWE Baskets Oldenburg   2015_001        3           1      162
# 301  EWE Baskets Oldenburg   2015_001        3           1      159
# 302  EWE Baskets Oldenburg   2015_001        3           1      157
# 303  EWE Baskets Oldenburg   2015_001        3          -1      155
# 304  EWE Baskets Oldenburg   2015_001        3          -1      138
# 305  EWE Baskets Oldenburg   2015_001        3          -1      138
# 306  EWE Baskets Oldenburg   2015_001        3          -1      138
# 307  EWE Baskets Oldenburg   2015_001        3          -1      138
# 308  EWE Baskets Oldenburg   2015_001        3           0      138
# 309  EWE Baskets Oldenburg   2015_001        3           1      138
# 310  EWE Baskets Oldenburg   2015_001        3           1      115
# 311  EWE Baskets Oldenburg   2015_001        3           1      113
# 312  EWE Baskets Oldenburg   2015_001        3           3      102
# 313  EWE Baskets Oldenburg   2015_001        3           3      102
# 314  EWE Baskets Oldenburg   2015_001        3           3      102
# 315  EWE Baskets Oldenburg   2015_001        3           3      102
# 316  EWE Baskets Oldenburg   2015_001        3           3      102
# 317  EWE Baskets Oldenburg   2015_001        3           3      102
# 318  EWE Baskets Oldenburg   2015_001        3           3      102
# 319  EWE Baskets Oldenburg   2015_001        3           3      102
# 320  EWE Baskets Oldenburg   2015_001        3           1       84
# 321  EWE Baskets Oldenburg   2015_001        3           1       70
# 322  EWE Baskets Oldenburg   2015_001        3           1       67
# 323  EWE Baskets Oldenburg   2015_001        3           1       62
# 324  EWE Baskets Oldenburg   2015_001        3           1       51
# 325  EWE Baskets Oldenburg   2015_001        3           1       51
# 326  EWE Baskets Oldenburg   2015_001        3           1       51
# 327  EWE Baskets Oldenburg   2015_001        3           1       51
# 328  EWE Baskets Oldenburg   2015_001        3           1       43
# 329  EWE Baskets Oldenburg   2015_001        3           1       43
# 330  EWE Baskets Oldenburg   2015_001        3           2       43
# 331  EWE Baskets Oldenburg   2015_001        3           2       43
# 332  EWE Baskets Oldenburg   2015_001        3           2       41
# 333  EWE Baskets Oldenburg   2015_001        3           2       41
# 334  EWE Baskets Oldenburg   2015_001        3           2       41
# 335  EWE Baskets Oldenburg   2015_001        3           3       41
# 336  EWE Baskets Oldenburg   2015_001        3           3       41
# 337  EWE Baskets Oldenburg   2015_001        3           3       39
# 338  EWE Baskets Oldenburg   2015_001        3           3       19
# 339  EWE Baskets Oldenburg   2015_001        3           3       19
# 340  EWE Baskets Oldenburg   2015_001        3           3        7
# 341  EWE Baskets Oldenburg   2015_001        3           3        2
# 342  EWE Baskets Oldenburg   2015_001        3           3        0
# 343  EWE Baskets Oldenburg   2015_001        3           1        0
# 344  EWE Baskets Oldenburg   2015_001        3           1        0
# 345  EWE Baskets Oldenburg   2015_001        3           1        0
# 346  EWE Baskets Oldenburg   2015_001        3           1        0
# 347  EWE Baskets Oldenburg   2015_001        3           3        0
# 348  EWE Baskets Oldenburg   2015_001        3           3        0
# 349  EWE Baskets Oldenburg   2015_001        3           3        0
# 350  EWE Baskets Oldenburg   2015_001        4           3      597
# 351  EWE Baskets Oldenburg   2015_001        4           3      597
# 352  EWE Baskets Oldenburg   2015_001        4           3      597
# 353  EWE Baskets Oldenburg   2015_001        4           3      597
# 354  EWE Baskets Oldenburg   2015_001        4           3      574
# 355  EWE Baskets Oldenburg   2015_001        4           3      571
# 356  EWE Baskets Oldenburg   2015_001        4           3      550
# 357  EWE Baskets Oldenburg   2015_001        4           3      550
# 358  EWE Baskets Oldenburg   2015_001        4           3      547
# 359  EWE Baskets Oldenburg   2015_001        4           3      545
# 360  EWE Baskets Oldenburg   2015_001        4           6      536
# 361  EWE Baskets Oldenburg   2015_001        4           6      513
# 362  EWE Baskets Oldenburg   2015_001        4           6      510
# 363  EWE Baskets Oldenburg   2015_001        4           6      496
# 364  EWE Baskets Oldenburg   2015_001        4           4      482
# 365  EWE Baskets Oldenburg   2015_001        4           4      480
# 366  EWE Baskets Oldenburg   2015_001        4           4      468
# 367  EWE Baskets Oldenburg   2015_001        4           4      466
# 368  EWE Baskets Oldenburg   2015_001        4           2      465
# 369  EWE Baskets Oldenburg   2015_001        4           2      465
# 370  EWE Baskets Oldenburg   2015_001        4           2      465
# 371  EWE Baskets Oldenburg   2015_001        4           2      465
# 372  EWE Baskets Oldenburg   2015_001        4           5      448
# 373  EWE Baskets Oldenburg   2015_001        4           5      429
# 374  EWE Baskets Oldenburg   2015_001        4           5      426
# 375  EWE Baskets Oldenburg   2015_001        4           5      413
# 376  EWE Baskets Oldenburg   2015_001        4           5      411
# 377  EWE Baskets Oldenburg   2015_001        4           5      395
# 378  EWE Baskets Oldenburg   2015_001        4           5      394
# 379  EWE Baskets Oldenburg   2015_001        4           5      394
# 380  EWE Baskets Oldenburg   2015_001        4           5      394
# 381  EWE Baskets Oldenburg   2015_001        4           5      394
# 382  EWE Baskets Oldenburg   2015_001        4           5      394
# 383  EWE Baskets Oldenburg   2015_001        4           5      394
# 384  EWE Baskets Oldenburg   2015_001        4           5      394
# 385  EWE Baskets Oldenburg   2015_001        4           5      394
# 386  EWE Baskets Oldenburg   2015_001        4           5      394
# 387  EWE Baskets Oldenburg   2015_001        4           5      385
# 388  EWE Baskets Oldenburg   2015_001        4           5      383
# 389  EWE Baskets Oldenburg   2015_001        4           7      370
# 390  EWE Baskets Oldenburg   2015_001        4           7      369
# 391  EWE Baskets Oldenburg   2015_001        4           7      369
# 392  EWE Baskets Oldenburg   2015_001        4           7      369
# 393  EWE Baskets Oldenburg   2015_001        4           7      369
# 394  EWE Baskets Oldenburg   2015_001        4           7      369
# 395  EWE Baskets Oldenburg   2015_001        4           7      355
# 396  EWE Baskets Oldenburg   2015_001        4           7      353
# 397  EWE Baskets Oldenburg   2015_001        4           7      336
# 398  EWE Baskets Oldenburg   2015_001        4           7      336
# 399  EWE Baskets Oldenburg   2015_001        4           7      319
# 400  EWE Baskets Oldenburg   2015_001        4           7      319
# 401  EWE Baskets Oldenburg   2015_001        4           7      305
# 402  EWE Baskets Oldenburg   2015_001        4           7      303
# 403  EWE Baskets Oldenburg   2015_001        4           7      302
# 404  EWE Baskets Oldenburg   2015_001        4           7      302
# 405  EWE Baskets Oldenburg   2015_001        4           7      290
# 406  EWE Baskets Oldenburg   2015_001        4           7      286
# 407  EWE Baskets Oldenburg   2015_001        4           7      278
# 408  EWE Baskets Oldenburg   2015_001        4           7      275
# 409  EWE Baskets Oldenburg   2015_001        4          10      263
# 410  EWE Baskets Oldenburg   2015_001        4          10      262
# 411  EWE Baskets Oldenburg   2015_001        4          10      262
# 412  EWE Baskets Oldenburg   2015_001        4          10      244
# 413  EWE Baskets Oldenburg   2015_001        4          10      242
# 414  EWE Baskets Oldenburg   2015_001        4          10      221
# 415  EWE Baskets Oldenburg   2015_001        4          10      218
# 416  EWE Baskets Oldenburg   2015_001        4          10      211
# 417  EWE Baskets Oldenburg   2015_001        4          10      209
# 418  EWE Baskets Oldenburg   2015_001        4          10      202
# 419  EWE Baskets Oldenburg   2015_001        4          10      202
# 420  EWE Baskets Oldenburg   2015_001        4          10      202
# 421  EWE Baskets Oldenburg   2015_001        4          10      202
# 422  EWE Baskets Oldenburg   2015_001        4          10      202
# 423  EWE Baskets Oldenburg   2015_001        4          10      202
# 424  EWE Baskets Oldenburg   2015_001        4          10      202
# 425  EWE Baskets Oldenburg   2015_001        4          10      202
# 426  EWE Baskets Oldenburg   2015_001        4          10      188
# 427  EWE Baskets Oldenburg   2015_001        4          10      186
# 428  EWE Baskets Oldenburg   2015_001        4           8      166
# 429  EWE Baskets Oldenburg   2015_001        4          11      145
# 430  EWE Baskets Oldenburg   2015_001        4          11      143
# 431  EWE Baskets Oldenburg   2015_001        4          11      133
# 432  EWE Baskets Oldenburg   2015_001        4          11      130
# 433  EWE Baskets Oldenburg   2015_001        4          11      114
# 434  EWE Baskets Oldenburg   2015_001        4          11      114
# 435  EWE Baskets Oldenburg   2015_001        4          12      114
# 436  EWE Baskets Oldenburg   2015_001        4          13      109
# 437  EWE Baskets Oldenburg   2015_001        4          13      102
# 438  EWE Baskets Oldenburg   2015_001        4          13      102
# 439  EWE Baskets Oldenburg   2015_001        4          13       90
# 440  EWE Baskets Oldenburg   2015_001        4          13       90
# 441  EWE Baskets Oldenburg   2015_001        4          13       90
# 442  EWE Baskets Oldenburg   2015_001        4          12       90
# 443  EWE Baskets Oldenburg   2015_001        4          12       69
# 444  EWE Baskets Oldenburg   2015_001        4          12       69
# 445  EWE Baskets Oldenburg   2015_001        4          12       69
# 446  EWE Baskets Oldenburg   2015_001        4          12       69
# 447  EWE Baskets Oldenburg   2015_001        4          11       69
# 448  EWE Baskets Oldenburg   2015_001        4          10       69
# 449  EWE Baskets Oldenburg   2015_001        4          13       51
# 450  EWE Baskets Oldenburg   2015_001        4          13       49
# 451  EWE Baskets Oldenburg   2015_001        4          11       31
# 452  EWE Baskets Oldenburg   2015_001        4          14       11
# 453  EWE Baskets Oldenburg   2015_001        4          14       11
# 454  EWE Baskets Oldenburg   2015_001        4          11        3
# 455  EWE Baskets Oldenburg   2015_001        4          11        3
# 456  EWE Baskets Oldenburg   2015_001        4          11        0
# 457              Fiat Turin  2017_001        1          11      600
# 458              Fiat Turin  2017_001        1          11      600
# 459              Fiat Turin  2017_001        1           3      596
# 460              Fiat Turin  2017_001        1           3      592
# 461              Fiat Turin  2017_001        1           1      558
# 462              Fiat Turin  2017_001        1           1      544
# 463              Fiat Turin  2017_001        1           1      542
# 464              Fiat Turin  2017_001        1           1      540
# 465              Fiat Turin  2017_001        1           1      536
# 466              Fiat Turin  2017_001        1           1      525
# 467              Fiat Turin  2017_001        1           1      519
# 468              Fiat Turin  2017_001        1          -1      507
# 469              Fiat Turin  2017_001        1          -1      484
# 470              Fiat Turin  2017_001        1          -1      482
# 471              Fiat Turin  2017_001        1          -1      477
# 472              Fiat Turin  2017_001        1          -1      477
# 473              Fiat Turin  2017_001        1          -2      477
# 474              Fiat Turin  2017_001        1          -2      477
# 475              Fiat Turin  2017_001        1          -3      477
# 476              Fiat Turin  2017_001        1          -1      451
# 477              Fiat Turin  2017_001        1          -1      449
# 478              Fiat Turin  2017_001        1          -1      442
# 479              Fiat Turin  2017_001        1          -1      442
# 480              Fiat Turin  2017_001        1          -1      442
# 481              Fiat Turin  2017_001        1          -1      442
# 482              Fiat Turin  2017_001        1          -1      442
# 483              Fiat Turin  2017_001        1          -1      442
# 484              Fiat Turin  2017_001        1          -1      442
# 485              Fiat Turin  2017_001        1          -1      441
# 486              Fiat Turin  2017_001        1          -1      384
# 487              Fiat Turin  2017_001        1          -1      382
# 488              Fiat Turin  2017_001        1           1      380
# 489              Fiat Turin  2017_001        1           1      354
# 490              Fiat Turin  2017_001        1           1      353
# 491              Fiat Turin  2017_001        1          -2      350
# 492              Fiat Turin  2017_001        1          -2      339
# 493              Fiat Turin  2017_001        1          -2      339
# 494              Fiat Turin  2017_001        1          -2      339
# 495              Fiat Turin  2017_001        1          -2      333
# 496              Fiat Turin  2017_001        1          -2      330
# 497              Fiat Turin  2017_001        1          -4      320
# 498              Fiat Turin  2017_001        1          -4      302
# 499              Fiat Turin  2017_001        1          -4      301

# %%
# First, let's see how many rows we have before cleaning
print(f"Original number of rows: {len(df)}")

# Create a copy of the df to work with
df_clean = df.copy()

# List of playtypes to remove
playtypes_to_remove = ["AS", "IN", "OUT", "TOUT", "TOUT_TV", "F", "AG", "FV"]

# Remove unnecessary playtypes
df_clean = df_clean[~df_clean["playtype"].isin(playtypes_to_remove)]

# Combine all technical fouls into CM
technical_fouls = ["CMT", "CMU", "C", "B", "CMD"]
df_clean["playtype"] = df_clean["playtype"].replace(technical_fouls, "CM")

# Let's see how many rows we have after cleaning
print(f"Number of rows after cleaning: {len(df_clean)}")

# Let's check the unique playtypes that remain to verify our cleaning
remaining_playtypes = sorted(df_clean["playtype"].unique())
print("\nRemaining playtypes:")
for pt in remaining_playtypes:
    count = len(df_clean[df_clean["playtype"] == pt])
    print(f"{pt}: {count} occurrences")

df = df_clean
# Out:
# Original number of rows: 511880
# Number of rows after cleaning: 351093
#
# Remaining playtypes:
# 2FGA: 35889 occurrences
# 2FGM: 39719 occurrences
# 3FGA: 29623 occurrences
# 3FGM: 16346 occurrences
# CM: 39072 occurrences
# D: 46986 occurrences
# FTA: 9546 occurrences
# FTM: 28467 occurrences
# O: 20326 occurrences
# OF: 3303 occurrences
# RV: 41675 occurrences
# ST: 13332 occurrences
# TO: 26809 occurrences

# %%
# Create a new dataframe to adjust "numberofplay"
new_df = df.copy()

# Update "numberofplay" within each "game_id"
new_df['numberofplay'] = new_df.groupby('game_id').cumcount() + 1
df = new_df

# %%
# Define the playtypes that stop the correction
stop_playtypes = ["2FGM", "3FGM", "FTM"]

# Create a function to correct points within each game_id
def correct_points(group):
    # Initialize the points
    points_a, points_b = 0, 0
    
    # Iterate over rows to update points
    for idx, row in group.iterrows():
        # Update points to 0 until a stop playtype is found
        if row["playtype"] in stop_playtypes:
            break
        group.at[idx, "points_a"] = points_a
        group.at[idx, "points_b"] = points_b
    
    return group

# Apply the correction function to each game_id group
new_df = new_df.groupby("game_id", group_keys=False).apply(correct_points)

# Display the updated dataframe
df = new_df
# Out:
# C:\Users\masii\AppData\Local\Temp\ipykernel_13040\573329788.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   new_df = new_df.groupby("game_id", group_keys=False).apply(correct_points)

# %%
# Define the required quarters
required_quarters = {1, 2, 3, 4}

# Identify the game_ids that have all four quarters
valid_game_ids = (
    new_df.groupby("game_id")["quarter"]
    .apply(lambda x: required_quarters.issubset(set(x)))
)

# Filter to keep only rows with valid game_ids
filtered_df = new_df[new_df["game_id"].isin(valid_game_ids[valid_game_ids].index)]

# Display the filtered dataframe
filtered_df.head()

# Count unique game_id values before and after filtering
original_game_ids = new_df["game_id"].nunique()
filtered_game_ids = filtered_df["game_id"].nunique()

# Calculate the number of dropped game_ids
dropped_game_ids = original_game_ids - filtered_game_ids

print(f"Number of game_id dropped: {dropped_game_ids}")

df = filtered_df
# Out:
# Number of game_id dropped: 3

# %%
# Filter out rows where playtype is "CM" or "OF"
df = df[~df["playtype"].isin(["CM", "OF"])]

df["playtype"].unique()
# Out:
# array(['TO', 'ST', '2FGM', '2FGA', 'O', '3FGA', 'D', 'RV', '3FGM', 'FTM',
#        'FTA'], dtype=object)

# %%
# Create a new column 'possession'
df['possession'] = df.apply(
    lambda row: 1 if row['team'] == row['teama'] else 2,
    axis=1
)

# Display the updated dataframe to verify
df.head()
# Out:
#    unnamed: 0  numberofplay    codeteam playtype                    team  \
# 0        1048             1  OLD              TO  EWE Baskets Oldenburg
# 1        1049             2  BON              ST    Telekom Baskets Bonn
# 2        1050             3  BON            2FGM    Telekom Baskets Bonn
# 4        1052             4  OLD            2FGM  EWE Baskets Oldenburg
# 5        1053             5  BON            2FGA    Telekom Baskets Bonn
#
#    minute markertime  points_a  points_b                          playinfo  \
# 0       1      09:46         0         0                      Turnover (1)
# 1       1      09:46         0         0                         Steal (1)
# 2       1      09:32         2         0         Two Pointer (1/1 -  2 pt)
# 4       1      09:22         2         2         Two Pointer (1/1 -  2 pt)
# 5       1      09:22         2         2  Missed Two Pointer (1/2 -  2 pt)
#
#                   teama                   teamb   game_id  quarter  \
# 0  Telekom Baskets Bonn  EWE Baskets Oldenburg   2015_001        1
# 1  Telekom Baskets Bonn  EWE Baskets Oldenburg   2015_001        1
# 2  Telekom Baskets Bonn  EWE Baskets Oldenburg   2015_001        1
# 4  Telekom Baskets Bonn  EWE Baskets Oldenburg   2015_001        1
# 5  Telekom Baskets Bonn  EWE Baskets Oldenburg   2015_001        1
#
#    plus_minus  seconds  possession
# 0           0      586           2
# 1           0      586           1
# 2           2      572           1
# 4           0      562           2
# 5           0      562           1

# %%
# Columns to drop
columns_to_drop = ['codeteam', 'teama', 'teamb', 'team']

# Drop the specified columns
df_dropped = df.drop(columns=columns_to_drop)

# Display the updated dataframe
df_dropped.head()
df = df_dropped

# %%
# ¡¡¡¡¡¡¡¡!!!!!!!!! Every row above this one MEANS that the df here saved already has them implemented in the data wrangling!!!
df.to_csv('eurocup.csv', index=False)

# %%
df.head()
# Out:
#    unnamed: 0  numberofplay playtype  minute markertime  points_a  points_b  \
# 0        1048             1       TO       1      09:46         0         0
# 1        1049             2       ST       1      09:46         0         0
# 2        1050             3     2FGM       1      09:32         2         0
# 4        1052             4     2FGM       1      09:22         2         2
# 5        1053             5     2FGA       1      09:22         2         2
#
#                            playinfo   game_id  quarter  plus_minus  seconds  \
# 0                      Turnover (1)  2015_001        1           0      586
# 1                         Steal (1)  2015_001        1           0      586
# 2         Two Pointer (1/1 -  2 pt)  2015_001        1           2      572
# 4         Two Pointer (1/1 -  2 pt)  2015_001        1           0      562
# 5  Missed Two Pointer (1/2 -  2 pt)  2015_001        1           0      562
#
#    possession
# 0           2
# 1           1
# 2           1
# 4           2
# 5           1
